# %% [markdown]
# # Python
# > by Callou - Oct 2025

# %% [markdown]
# ## Practice 2

# %% [markdown]
# Exercise 1: List Operations
#
# Create a list of 5 favorite movies. Then:
#
# * Add a new movie using append()
#
# * Remove the second movie
#
# * Print the first and last movies using indexing
#
# * Print the total number of movies

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 2: Tuple Unpacking
#
# Create a tuple with your name, age, and city. Then:
#
# * Unpack it into three separate variables
#
# * Print each variable with a descriptive label
#
# * Try to change the age value (observe the error)

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 3: Dictionary Practice
#
# Create a dictionary representing a student with keys: "name", "age", "grade", and "subjects" (list of 3 subjects). Then:
#
# * Print the student's name
#
# * Add a new key "email" with a value
#
# * Update the grade
#
# * Print all keys and values using .items()

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 4: Grade Classifier
#
# Write a program that:
#
# * Asks the user for their exam score (0-100)
#
# * Uses if-elif-else to classify into: "A" (90+), "B" (80-89), "C" (70-79), "D" (60-69), "F" (<60)
#
# * Stores the result in a dictionary with keys "score" and "grade"
#
# * Prints: "You scored [score] and received a [grade]"

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 5: Shopping Cart
#
# Create an empty list called cart. Then:
#
# * Add 4 items (as strings) to the cart
#
# * Ask the user which item to remove
#
# * Use a conditional to check if the item exists before removing it
#
# * Print "Item removed" or "Item not found"
#
# * Print the final cart contents

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 6: Student Database
#
# * Create a dictionary where keys are student names and values are their test scores (integers). Include 4 students. Then:
#
# * Find and print the highest score using max() on .values()
#
# * Use a conditional to check if a specific student exists
#
# * Add a new student if they don't exist
#
# * Print all students who scored above 80

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# Exercise 7: Nested Conditionals with Collections
#
# Create a list of dictionaries, each representing a product with "name", "price", and "in_stock" (boolean). Include 5 products. Then:
#
# * Loop through the products
#
# * Use nested conditionals to:
#
# * Check if in stock
#
# * If yes, check if price < 50: print "Affordable!"
#
# * If price >= 50: print "Premium item"
#
# * If not in stock: print "Out of stock"

# %%
# CALL YOUR ANSWER HERE

# %% [markdown]
# ## Assignment 2

# %% [markdown]
# It's a quiz that will launched on Teams tomorrow.
