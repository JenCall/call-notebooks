# %% [markdown]
# > Pandas - by Callou

# %% [markdown]
# > Dataset source - https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas

# %% [markdown]
# Make a copy of the Dataset *telecom_churn.csv* through the link:
# > https://drive.google.com/file/d/1nCR03JnL41DS0aik14M5iFoOwBvYyoyw/view?usp=sharing

# %% [markdown]
# First, let's set up the environment. We'll import `numpy` and `pandas`, and set the display precision for pandas DataFrames. What are these libraries commonly used for in data analysis?

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# Now, we load the data from 'telecom_churn.csv' into a pandas DataFrame called `df` and display the first few rows. What information can we gather from the head of the DataFrame?

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# Let's get a statistical summary of the numerical columns in the DataFrame. What insights can `describe` method provide about the data distribution and potential outliers?

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# Check the shape of the DataFrame. What does the output tell us about the size of our dataset?

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# Viewing the column names helps us understand the features available in the dataset. How to list the columns?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We can also check the data type of the DataFrame's columns.

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Which method provides a concise summary of the DataFrame, including the data types and non-null values for each column? What can we learn about the data's completeness and structure from this output?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Let's examine the 'Churn' column. What does the output show us about this column?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We convert the 'Churn' column from boolean to integer type.

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Why might we want to represent 'Churn' as an integer (0 or 1) instead of a boolean (True or False)?

# %% [markdown]
# Text Answer

# %% [markdown]
# Now that 'Churn' is an integer, let's look at the column again. What does the output now show after the type conversion?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Counting the values in the 'Churn' column reveals the distribution of churned and loyal customers. What it tell us about the class balance in our dataset?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Let's look at the normalized value counts for the 'Churn' column. What percentage of customers have churned or remained loyal, according to `df["Churn"].value_counts(normalize=True)`?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We sort the DataFrame by 'Total day charge' in descending order and display the top 10 rows. What can we observe about the customers with the highest day charges?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We calculate the mean of the 'Churn' column. Since 'Churn' is represented as 0 and 1, what does the result of `df["Churn"].mean()` signify?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# To find the average daytime minutes for churned users, we filter the DataFrame and calculate the mean of 'Total day minutes'. What is the average daytime phone time for customers who have churned?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We filter for loyal users (Churn == 0) who do not have an international plan and find the maximum length of their international calls. What is the longest international call made by a loyal user without an international plan?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# Let's select a subset of the DataFrame using integer-location based indexing (`iloc`). What does `df.iloc[0:5, 0:3]` extract from the DataFrame?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We apply the `np.max` function to each column of the DataFrame. What does it show us about the maximum value in each column?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We filter the DataFrame to show rows where the 'State' starts with the letter 'W' and display the first 10. What states are included in this filtered view?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We get the unique values of the 'State' column for rows where the state starts with 'W'. What does `df[df["State"].apply(lambda state: state[0] == "W")]["State"].unique()` confirm about the states we filtered for?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We group the DataFrame by the 'State' column and attempt to print each group. What does the output of `df_grouped.apply(print)` show us about the grouping operation, and why might there be a warning?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# We use `get_group('MA')` to select the group corresponding to the state 'MA'. What information does this provide about customers in Massachusetts?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# How to see only the 5 first entries of the dataset?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# What does `df.index` tell us about the structure of the DataFrame?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# How are we preparing the data for machine learning by separating features (`X`) and target (`y`)?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# What are the dimensions of our feature and target arrays after separation?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# How and why do we need to import `train_test_split` from `sklearn.model_selection`?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# How do we split the data into training and testing sets, and what does `random_state` ensure?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# What are the dimensions of the training sets for features and target?

# %%
 # CALL YOUR CODE HERE

# %% [markdown]
# What are the dimensions of the testing sets for features and target?

# %%
 # CALL YOUR CODE HERE
