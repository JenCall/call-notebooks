# %% [markdown]
# ## Binary classification
#
# - Examine a dataset containing measurements derived from images of two species of Turkish rice.
# - Create a ML model to sort grains of rice into the two species.
# - Evaluate the performance of the model.
#
# Write your answers on #CALL YOUR CODE HERE or #CALL YOUR ANSWER HERE

# %% [markdown]
# ## Load Imports

# %% [markdown]
# ### Install required libraries

# %%
# CALL YOUR CODE HERE (if needed)

# %% [markdown]
# ###Load libraries

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ###Load the dataset
#
# In this task we use the Cinar and Koklu 2019 Osmancik and Cammeo rice dataset.
#
# See on [Kaggle](https://www.kaggle.com/datasets/muratkokludataset/rice-dataset-commeo-and-osmancik) for more documentation; lengths and area are given in pixels). Cinar and Koklu also provide datasets for multiclass (5 species of rice), pistachios, raisins, grape leaves, and so on, at their [repository](https://www.muratkoklu.com/datasets/).

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Explore the dataset

# %% [markdown]
# Once the dataset has been loaded, select specific columns to show summary statistics of the numerical features in the dataset.
# Use at least 5 methods that helps you to explore the data ;)

# %%
# One idea:
rice_dataset = dataset_name[[
    'Area',
    'Perimeter',
    'Major_Axis_Length',
    'Minor_Axis_Length',
    'Eccentricity',
    'Convex_Area',
    'Extent',
    'Class',
]]

rice_dataset.describe()

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Visualize
#
# Plot at least 3 charts from dataset ;)

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Define X & y
#
# We'll arbritrarily assign the Cammeo species a label of '1' and the Osmancik species a label of '0'.

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Train & Test Split

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# We can then randomize and partition the dataset into train and test splits, consisting of 80%, 20% of the dataset respectively.
# random state = 42

# %% [markdown]
# It's important to prevent the model from getting the label as input during training, which is called label leakage. This can be done by storing features and labels as separate variables.

# %% [markdown]
# ##Prepare the data
# Which steps are part of the data preparation?
# Describe and implement it:

# %%
# CALL YOUR CODE HERE

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Train the model

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Test the model

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Predict the model

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Explain your findings

# %%
# CALL YOUR CODE HERE

# %% [markdown]
# ## Missing steps(?)
# can you identify any missing steps, or additional ones we could add?

# %% [markdown]
# CALL YOUR ANSWER HERE

# %% [markdown]
# ## What are other real life problems that this model can help you solve?

# %% [markdown]
# CALL YOUR ANSWER HERE

# %% [markdown]
# ## **END**

# %% [markdown]
# > For educational purposes - by Callou

# %% [markdown]
# ### Citation
#
# Cinar, I. and Koklu, M., (2019). “Classification of Rice Varieties Using Artificial Intelligence Methods.” *International Journal of Intelligent Systems and Applications in Engineering*, 7(3), 188-194.
#
# DOI: https://doi.org/10.18201/ijisae.2019355381
